# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sns.set_style('darkgrid')

# %%
# import csv file

train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
print("train:",train.shape)
print("test:",test.shape)
# Out:
# train: (891, 12)
# test: (418, 11)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# correlation heatmap

plt.subplots(figsize=(10, 10))
sns.heatmap(train.corr(), square = True, annot = True, fmt = ".2f", center = 0, cmap = "RdYlGn")
# Out:
# /tmp/ipykernel_10785/2230446493.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train.corr(), square = True, annot = True, fmt = ".2f", center = 0, cmap = "RdYlGn")
# <AxesSubplot: >

# %% [markdown]
# Note: Passenger class and Fare is more correlate to survived than other features

# %% [markdown]
# # Data Pre-Processing

# %%
for x in train:
    print(x)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
# drop unnecessary column

train=train.drop(['Name','Ticket'],axis=1)
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %% [markdown]
# ## Handling Null Value

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Cabin        204 non-null    object
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.drop('Cabin',axis=1,inplace=True)  # dropping 'Cabin' Because it has too many null value

# %%
sns.boxplot(data=train,x="Age")
# Out:
# <AxesSubplot: xlabel='Age'>

# %%
train['Age'].median()
# Out:
# 28.0

# %%
train['Age'] = train['Age'].fillna(train['Age'].median())

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
train=train.dropna()

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# converting value to integers
    
train['Survived']=train['Survived'].astype(int)

# %%
train['Survived'].unique()
# Out:
# array([0, 1])

# %%
train['Survived'].value_counts()
# Out:
# 0    549
# 1    340
# Name: Survived, dtype: int64

# %%
sns.countplot(x="Survived",data=train)
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='count'>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
train.shape
# Out:
# (889, 9)

# %%
# correlation heatmap
# after handling missing value

plt.subplots(figsize=(10, 10))
sns.heatmap(train.corr(), square = True, annot = True, fmt = ".2f", center = 0, cmap = "RdYlGn")
# Out:
# /tmp/ipykernel_10785/4004510562.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train.corr(), square = True, annot = True, fmt = ".2f", center = 0, cmap = "RdYlGn")
# <AxesSubplot: >

# %% [markdown]
# Note: Passenger class and Fare is more correlate to survived than other features

# %%
train['Survived_or_Not']=train['Survived']

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked  Survived_or_Not
# 0        S                0
# 1        C                1
# 2        S                1
# 3        S                1
# 4        S                0

# %%
sns.countplot(x="Survived_or_Not",data=train)
# Out:
# <AxesSubplot: xlabel='Survived_or_Not', ylabel='count'>

# %% [markdown]
# ### Survivor Count

# %%
train['Survived_or_Not'].replace({0:'Not Survived',1:'Survived'},inplace=True)

# %%
train['Survived_or_Not'].head(2)
# Out:
# 0    Not Survived
# 1        Survived
# Name: Survived_or_Not, dtype: object

# %%
train["Survived_or_Not"].value_counts()
# Out:
# Not Survived    549
# Survived        340
# Name: Survived_or_Not, dtype: int64

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='Survived_or_Not',data=train)
# Out:
# <AxesSubplot: xlabel='Survived_or_Not', ylabel='count'>

# %% [markdown]
# ## Passenger class

# %%
# passenger class

train['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='Pclass',data=train)
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %%
# Correlation to survived
train['Pclass'].corr(train['Survived'])
# Out:
# -0.33554885935682505

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="Pclass",hue="Survived_or_Not",data=train,palette='bright')
plt.legend(loc='upper right')

# %% [markdown]
# ## Sibsp

# %%
train['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
plt.figure(figsize=(7,7))
sns.countplot(train['SibSp'])
# Out:
# <AxesSubplot: ylabel='count'>

# %%
# Correlation to survived

train['SibSp'].corr(train['Survived'])
# Out:
# -0.034039998796749

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="SibSp",hue="Survived_or_Not",data=train,palette='bright')
plt.legend(loc='upper right')

# %% [markdown]
# ## Parch

# %%
train['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='Parch',data=train)
# Out:
# <AxesSubplot: xlabel='Parch', ylabel='count'>

# %%
train['Parch'].value_counts()
# Out:
# 0    676
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
# Correlation to survived

train['Parch'].corr(train['Survived'])
# Out:
# 0.08315078366620243

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="Parch",hue="Survived_or_Not",data=train,palette='bright')
plt.legend(loc='upper right')

# %%
train['Survived'].groupby(train['Parch']).sum().sort_values(ascending=False)
# Out:
# Parch
# 0    231
# 1     65
# 2     40
# 3      3
# 5      1
# 4      0
# 6      0
# Name: Survived, dtype: int64

# %% [markdown]
# ## Embarked

# %%
train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='Embarked',data=train)
# Out:
# <AxesSubplot: xlabel='Embarked', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="Embarked",hue='Survived_or_Not',data=train,palette='bright')
plt.legend(loc='upper right')

# %% [markdown]
# ## Sex

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='Sex',data=train)
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='count'>

# %%
train['Survived'].groupby(train['Sex']).sum().sort_values(ascending=False)
# Out:
# Sex
# female    231
# male      109
# Name: Survived, dtype: int64

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="Sex",hue='Survived_or_Not',data=train,palette='bright')
plt.legend(loc='upper right')

# %% [markdown]
# ## Age

# %%
train['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  , 28.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  ,  8.  ,
#        19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  , 49.  ,
#        29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  , 16.  ,
#        25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  , 71.  ,
#        37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 , 51.  ,
#        55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  , 45.5 ,
#        20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  , 60.  ,
#        10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  , 70.  ,
#        24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
sns.displot(data=train, x="Age",height=5, aspect=2)

# %%
# Correlation to survived

train['Age'].corr(train['Survived'])
# Out:
# -0.06982170767891913

# %%
sns.displot(data=train, x="Age",hue="Survived",kind="hist",kde=True,palette="bright",height=5, aspect=2)

# %% [markdown]
# ## Fare

# %%
train['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  83.475 ,  27.9   ,
#         15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,  56.4958,
#          7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,   7.7875,
#         47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,  34.6542,
#         63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,  24.15  ,
#          9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,   6.975 ,
#          7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,  79.2   ,
# ...

# %%
train['Fare'].mean()
# Out:
# 32.09668087739032

# %%
train['Fare'].median()
# Out:
# 14.4542

# %%
train['Fare'].max()
# Out:
# 512.3292

# %%
train['Fare'].min()
# Out:
# 0.0

# %%
train[train['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass   Sex   Age  SibSp  Parch  Fare Embarked  \
# 179          180         0       3  male  36.0      0      0   0.0        S
# 263          264         0       1  male  40.0      0      0   0.0        S
# 271          272         1       3  male  25.0      0      0   0.0        S
# 277          278         0       2  male  28.0      0      0   0.0        S
# 302          303         0       3  male  19.0      0      0   0.0        S
# 413          414         0       2  male  28.0      0      0   0.0        S
# 466          467         0       2  male  28.0      0      0   0.0        S
# 481          482         0       2  male  28.0      0      0   0.0        S
# 597          598         0       3  male  49.0      0      0   0.0        S
# 633          634         0       1  male  28.0      0      0   0.0        S
# 674          675         0       2  male  28.0      0      0   0.0        S
# ...

# %%
sns.displot(data=train, x="Fare",height=5, aspect=2)

# %%
train['Fare'].corr(train['Survived'])
# Out:
# 0.2552904613046991

# %%
sns.displot(data=train, x="Fare",hue="Survived",kind="hist",kde=True,height=5, aspect=2)

# %%
sns.pairplot(train,hue='Survived')

# %%
train.head(2)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
#
#   Embarked Survived_or_Not
# 0        S    Not Survived
# 1        C        Survived

# %%
train.drop('Survived_or_Not',axis=1,inplace=True)

# %%
train.head(2)
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0  22.0      1      0   7.2500         0
# 1            2         1       1    1  38.0      1      0  71.2833         1

# %%
train['Embarked'].unique()
# Out:
# array([0, 1, 2])

# %%
train['Sex'].replace({'male':0,'female':1},inplace=True)
train['Embarked'].replace({'S':0,'C':1,'Q':2},inplace=True)

# %%
train.head(2)
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0  22.0      1      0   7.2500         0
# 1            2         1       1    1  38.0      1      0  71.2833         1

# %%
# # Dividing dependent and independent variables

X = train.drop("Survived", axis=1)
y = train["Survived"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100,random_state=0)
random_forest_model=clf.fit(X_train, y_train)
y_pred=random_forest_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

acc_score=accuracy_score(y_test, y_pred)
p_score=precision_score(y_test,y_pred)
re_score=recall_score(y_test,y_pred)
f_score=f1_score(y_test,y_pred)

print(f'Accuracy score of the model is {acc_score}')
print(f'precision score of the model is {p_score}')
print(f'recall score of the model is {re_score}')
print(f'f1_score of the model is {f_score}')
# Out:
# Accuracy score of the model is 0.7921348314606742
# precision score of the model is 0.7285714285714285
# recall score of the model is 0.7391304347826086
# f1_score of the model is 0.7338129496402879

# %%
confusion_m=confusion_matrix(y_test,y_pred)
confusion_m
# Out:
# array([[90, 19],
#        [18, 51]], dtype=int64)

# %%
x_axis_labels = ['Not Survived','Survived']
y_axis_labels =  ['Not Survived','Survived']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='Greens', xticklabels=x_axis_labels, yticklabels=y_axis_labels)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
dt_model = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = dt_model.predict(X_test)

# %%
acc_score=accuracy_score(y_test, y_pred)
p_score=precision_score(y_test,y_pred)
re_score=recall_score(y_test,y_pred)
f_score=f1_score(y_test,y_pred)

print(f'Accuracy score of the model is {acc_score}')
print(f'precision score of the model is {p_score}')
print(f'recall score of the model is {re_score}')
print(f'f1_score of the model is {f_score}')
# Out:
# Accuracy score of the model is 0.7134831460674157
# precision score of the model is 0.6125
# recall score of the model is 0.7101449275362319
# f1_score of the model is 0.6577181208053692

# %%
x_axis_labels = ['Not Survived','Survived']
y_axis_labels =  ['Not Survived','Survived']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='Greens', xticklabels=x_axis_labels, yticklabels=y_axis_labels)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

clf= LogisticRegression()
logistic_model=clf.fit(X_train,y_train)
y_pred=logistic_model.predict(X_test)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
acc_score=accuracy_score(y_test, y_pred)
p_score=precision_score(y_test,y_pred)
re_score=recall_score(y_test,y_pred)
f_score=f1_score(y_test,y_pred)

print(f'Accuracy score of the model is {acc_score}')
print(f'precision score of the model is {p_score}')
print(f'recall score of the model is {re_score}')
print(f'f1_score of the model is {f_score}')
# Out:
# Accuracy score of the model is 0.7921348314606742
# precision score of the model is 0.7285714285714285
# recall score of the model is 0.7391304347826086
# f1_score of the model is 0.7338129496402879

# %%
x_axis_labels = ['Not Survived','Survived']
y_axis_labels =  ['Not Survived','Survived']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='Greens', xticklabels=x_axis_labels, yticklabels=y_axis_labels)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

clf= KNeighborsClassifier(n_neighbors=25)

# Train the model using the training sets
knn_model=clf.fit(X_train,y_train)

y_pred=knn_model.predict(X_test)

# %%
acc_score=accuracy_score(y_test, y_pred)
p_score=precision_score(y_test,y_pred)
re_score=recall_score(y_test,y_pred)
f_score=f1_score(y_test,y_pred)

print(f'Accuracy score of the model is {acc_score}')
print(f'precision score of the model is {p_score}')
print(f'recall score of the model is {re_score}')
print(f'f1_score of the model is {f_score}')
# Out:
# Accuracy score of the model is 0.6685393258426966
# precision score of the model is 0.7083333333333334
# recall score of the model is 0.2463768115942029
# f1_score of the model is 0.36559139784946243

# %%
x_axis_labels = ['Not Survived','Survived']
y_axis_labels =  ['Not Survived','Survived']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='Greens', xticklabels=x_axis_labels, yticklabels=y_axis_labels)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Xgboost

# %%
from xgboost import XGBClassifier


# fit model no training data
clf = XGBClassifier(
              learning_rate=0.300000012,n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
             )
xgboost_model=clf.fit(X_train, y_train)

xgboost_model.fit(X_train, y_train)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:31:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
acc_score=accuracy_score(y_test, y_pred)
p_score=precision_score(y_test,y_pred)
re_score=recall_score(y_test,y_pred)
f_score=f1_score(y_test,y_pred)

print(f'Accuracy score of the model is {acc_score}')
print(f'precision score of the model is {p_score}')
print(f'recall score of the model is {re_score}')
print(f'f1_score of the model is {f_score}')
# Out:
# Accuracy score of the model is 0.6685393258426966
# precision score of the model is 0.7083333333333334
# recall score of the model is 0.2463768115942029
# f1_score of the model is 0.36559139784946243

# %%
x_axis_labels = ['Not Survived','Survived']
y_axis_labels =  ['Not Survived','Survived']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='Greens', xticklabels=x_axis_labels, yticklabels=y_axis_labels)
# Out:
# <AxesSubplot:>
